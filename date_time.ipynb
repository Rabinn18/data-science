# %% [markdown]
# # Working With Datetimes

# %% [raw]
# Question:
# ->Import the datetime.datetime class using the alias dt.
# ->Instantiate a datetime object representing midnight on June 16, 1911. Assign the object to the variable name ibm_founded.
# ->Instantiate a datetime object representing 8:17 p.m. on July 20, 1969. Assign the object to the variable name man_on_moon.

# %%
from datetime import datetime

# %%
dtobj = datetime(1933,4,5)

# %%
print(type(dtobj))
# Out:
# <class 'datetime.datetime'>

# %%
dtobj2 = datetime(1944,10,5,13,3)

# %%
print(dtobj2)
# Out:
# 1944-10-05 13:03:00

# %%
from datetime import datetime as dt

# %%
ibm_founded = datetime(1911,6,16)

# %%
print(ibm_founded)
# Out:
# 1911-06-16 00:00:00

# %%
print(type(ibm_founded))
# Out:
# <class 'datetime.datetime'>

# %%
man_on_moon = datetime(1969,7,20,8,17)

# %%
print(man_on_moon)
# Out:
# 1969-07-20 08:17:00

# %%
dt3 = "March 28, 1977"

# %%
months = ["January", "February", "March", "April", "May", "June",
         "July", "August", "September", "October", "November", "December"]

# %%
type(months.index('March') + 1)
# Out:
# int

# %%
month_day, year = dt3.split(',')

# %%
month, day = month_day.split(' ')

# %%
month = months.index(month) + 1

# %%
dt4 = dt(int(year), month, int(day))

# %%
print(dt4)
# Out:
# 1977-03-28 00:00:00

# %%
dateobj = "2054/12/15"

# %%
dateobj_to_date = datetime.strptime(dateobj, "%Y/%m/%d")

# %%
dateobj_to_date
# Out:
# datetime.datetime(2054, 12, 15, 0, 0)

# %%
dateobj2 = "March 28, 1998"

# %%
dateobj_to_date = datetime.strptime(dateobj2, "%B %d, %Y")

# %%
print(dateobj_to_date)
# Out:
# 1998-03-28 00:00:00

# %%
date3 = "March 28,1998,9:15"

# %%
dateobj_to_date3 = datetime.strptime(date3, "%B %d,%Y,%H:%M")

# %%
print(dateobj_to_date3)
# Out:
# 1998-03-28 09:15:00

# %%
csv_file = open('appointment_schedule.csv')

# %%
from datetime import datetime

# %%
from csv import reader

# %%
data = reader(csv_file)

# %%
dataset = list(data)
print(dataset)
# Out:
# [['name', 'appointment_made_date', 'app_start_date', 'app_end_date', 'visitee_namelast', 'visitee_namefirst', 'meeting_room', 'description'], ['Joshua T. Blanton', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Jack T. Gutting', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Bradley T. Guiles', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Loryn F. Grieb', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Travis D. Gordon', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Taylor D. Gibbs', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Dameriah A. Smith', '2
# ...

# %%
date1 = []
for i in dataset[1:]:
    date1.append(i[2])
    
print(date1)
# Out:
# ['1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15 9:30', '1/6/15
# ...

# %% [raw]
# Question
# ->Create a string date_format that specifies the format of the appt_start_date column:
# ->The format of the app_start_date column is {month}/{day}/{two digit year} {hour 24hr time}:{minute}.->
# ->Substitute each of the values inside braces with the appropriate strftime code from the table above.
# ->Read the appointment_schedule.csv file using csv reader and iterate over each row in the list of lists.
# ->Assign the appt_start_date column, found at index 2 of each row, to a variable.
# ->Use the datetime.strptime() constructor to convert the variable from a string to a datetime object, using the date_format ->string you created earlier.
# ->Assign the datetime object back to index 2 of the row.

# %%
for item in dataset[1:5]:
    print(item)
# Out:
# ['Joshua T. Blanton', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard']
# ['Jack T. Gutting', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard']
# ['Bradley T. Guiles', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard']
# ['Loryn F. Grieb', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard']

# %%
for item in dataset[1:]:
    item[2] = datetime.strptime(item[2], "%m/%d/%y %H:%M")

# %%
for item in dataset[1:5:]:
    print (item)
# Out:
# ['Joshua T. Blanton', '2014-12-18T00:00:00', datetime.datetime(2015, 1, 6, 9, 30), '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard']
# ['Jack T. Gutting', '2014-12-18T00:00:00', datetime.datetime(2015, 1, 6, 9, 30), '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard']
# ['Bradley T. Guiles', '2014-12-18T00:00:00', datetime.datetime(2015, 1, 6, 9, 30), '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard']
# ['Loryn F. Grieb', '2014-12-18T00:00:00', datetime.datetime(2015, 1, 6, 9, 30), '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard']

# %%
from datetime import datetime
dstring = "2054/12/15"

# %%
dsobject = datetime.strptime(dstring, "%Y/%m/%d")
dsobject
# Out:
# datetime.datetime(2054, 12, 15, 0, 0)

# %%
dsobject.year
# Out:
# 2054

# %%
dsobject.month
# Out:
# 12

# %% [raw]
# q) convert December 24, 1999 --> 12/24/1999

# %%
demoDate = "December 24, 1999"

# %%
objDate = datetime.strptime(demoDate, "%B %d, %Y")
objDate
# Out:
# datetime.datetime(1999, 12, 24, 0, 0)

# %%
objDate_to_date3 = datetime.strftime(objDate, "%m/%d/%Y")

# %%
print(objDate_to_date3)
# Out:
# 12/24/1999

# %% [raw]
# Question
# ->Initialize an empty dictionary: visitors_per_month.
# ->Iterate over the rows in the appointment_dataset which is list of lists.
# ->In each iteration, do the following:
#     i)Assign the datetime object from the appt_start_date column (index 2) to a variable.
#     ii)Call the datetime.strftime() method on the appt_start_date object to create a string in the format "January,1901.
#     iii)The format code for the name of the month is %B.
#     iv)The format code for a four-digit year is %Y.
#     v)If the string is not a key in visitors_per_month, add it as a key with a value of 1. Otherwise, add 1 to the existing value for that key.

# %%
from datetime import datetime
from csv import reader

# %%
csv_file = open('appointment_schedule.csv')

# %%
data = reader(csv_file)
dataset = list(data)

# %%
print(dataset)
# Out:
# [['name', 'appointment_made_date', 'app_start_date', 'app_end_date', 'visitee_namelast', 'visitee_namefirst', 'meeting_room', 'description'], ['Joshua T. Blanton', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Jack T. Gutting', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Bradley T. Guiles', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Loryn F. Grieb', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Travis D. Gordon', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Taylor D. Gibbs', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Dameriah A. Smith', '2
# ...

# %%
visitors_per_month = {}
for item in dataset[1:]:
    item[2] = datetime.strptime(item[2], "%m/%d/%y")
#     print(item[2])
    if item[2] not in visitors_per_month:
        visitors_per_month[item[2]] = 1
    else:
        visitors_per_month[i[2]] += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21936\614460729.py in <module>
#       1 visitors_per_month = {}
#       2 for item in dataset[1:]:
# ----> 3     item[2] = datetime.strptime(item[2], "%m/%d/%y")
#       4 #     print(item[2])
#       5     if item[2] not in visitors_per_month:
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %% [markdown]
# The Time Class

# %%
from datetime import time

# %%
datetime.today()
# Out:
# datetime.datetime(2022, 12, 27, 13, 16, 11, 254021)

# %%
time_now = time(13, 18, 59, 1000)

# %%
print(time_now)
# Out:
# 13:18:59.001000

# %% [raw]
# Question
# ->Instantiate an empty appt_times list.
# ->Iterate over each row in the appointment_datasets list of lists. For each iteration, do the following:
#     i)Assign the datetime object stored at index value 2 to a variable.
#     ii)Create a time object from the datetime object.
#     iii)Append the time object to the appt_times list.

# %%
from datetime import datetime
from csv import reader
csv_file = open('appointment_schedule.csv')
data = reader(csv_file)
dataset = list(data)

# %%
print(dataset)
# Out:
# [['name', 'appointment_made_date', 'app_start_date', 'app_end_date', 'visitee_namelast', 'visitee_namefirst', 'meeting_room', 'description'], ['Joshua T. Blanton', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Jack T. Gutting', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Bradley T. Guiles', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Loryn F. Grieb', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Travis D. Gordon', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Taylor D. Gibbs', '2014-12-18T00:00:00', '1/6/15 9:30', '1/6/15 23:59', '', 'potus', 'west wing', 'JointService Military Honor Guard'], ['Dameriah A. Smith', '2
# ...

# %%
from datetime import time
appt_times = []
for item in dataset[1:]:
    var1 = item[2]
#     print(var1)
    var1 = time(var1.hour , var1.minute)
    appt_times.append(var1)

# %%
appt_times
# Out:
# []

# %% [markdown]
# Comparing Date & Time Objects

# %%
from datetime import time

# %%
time1 = time(14,22)
time2 = time(15,11)

# %%
time1>time2
# Out:
# False

# %%
from datetime import datetime

# %%
datetime1 = datetime(2031,3,5,4,5)
datetime2 = datetime(2031,12,2,4,2)

# %%
datetime1>datetime2
# Out:
# False

# %% [raw]
# Q) Use the appt_times list and find out the maximum and minimum appointment times from the given list.

# %%
appt_times_max = max(appt_times)
print(appt_times_max)
#use min() for appt_times_min
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21936\1835123318.py in <module>
# ----> 1 appt_times_max = max(appt_times)
#       2 print(appt_times_max)
#
# ValueError: max() arg is an empty sequence

# %% [markdown]
# Calculations with Dates and Times

# %%
from datetime import datetime, time, timedelta

# %% [raw]
# q) calculate startdate and enddate from "March 28, 1998"
